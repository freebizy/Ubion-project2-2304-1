# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, LSTM,Dropout
from keras.optimizers import Adam

from sklearn.preprocessing import Binarizer
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score
from sklearn.metrics import accuracy_score, f1_score, recall_score,precision_score
from sklearn.metrics import precision_recall_curve,roc_curve,confusion_matrix ,auc

# %%
def plot_pr_auc_curve(y_true, y_pred_proba):
    # Calculate precision, recall and threshold values
    precision, recall, thresholds = precision_recall_curve(y_true, y_pred_proba)
    # Calculate PR-AUC score
    pr_auc = auc(recall, precision)
    # Plot the PR-AUC curve
    plt.plot(recall, precision, label=f'PR-AUC = {pr_auc:.2f}')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('PR-AUC Curve')
    plt.legend()
    plt.show()

def get_pr_auc_score(y_true, y_pred_proba):
    # Calculate precision, recall and threshold values
    precision, recall, thresholds = precision_recall_curve(y_true, y_pred_proba)
    # Calculate PR-AUC score
    pr_auc = auc(recall, precision)
    return pr_auc

# %%
def eval(test,pred):
    acc = accuracy_score(test,pred)
    f1 = f1_score(test,pred)
    precision = precision_score(test,pred)
    recall = recall_score(test,pred)
    print('##############\n',confusion_matrix(test,pred),
    "############\n",f'acc_score: {acc}\n f1_score: {f1} \n precision: {precision} \n recall: {recall}')

## 임계값 =[] 리스트생성 후 for 구문
def get_eval_by_threshold(y_test , pred_proba_c1, thresholds=[0.5,0.52,0.54,0.56,0.58,0.6,0.62]):
    # thresholds list객체내의 값을 차례로 iteration하면서 Evaluation 수행.
    for custom_threshold in thresholds:
        binarizer = Binarizer(threshold=custom_threshold).fit(pred_proba_c1) 
        custom_predict = binarizer.transform(pred_proba_c1)
        print('임곗값:',custom_threshold)
        eval(y_test , custom_predict)


def precision_recall_curve_plot(y_test , pred_proba_c1):
    # threshold ndarray와 이 threshold에 따른 정밀도, 재현율 ndarray 추출. 
    precisions, recalls, thresholds = precision_recall_curve( y_test, pred_proba_c1)
    
    # X축을 threshold값으로, Y축은 정밀도, 재현율 값으로 각각 Plot 수행. 정밀도는 점선으로 표시
    plt.figure(figsize=(8,6))
    threshold_boundary = thresholds.shape[0]
    plt.plot(thresholds, precisions[0:threshold_boundary], linestyle='--', label='precision')
    plt.plot(thresholds, recalls[0:threshold_boundary],label='recall')
    
    # threshold 값 X 축의 Scale을 0.1 단위로 변경
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1),2))
    
    # x축, y축 label과 legend, 그리고 grid 설정
    plt.xlabel('Threshold value'); plt.ylabel('Precision and Recall value')
    plt.legend(); plt.grid()
    plt.show()
    

## roc curve_plot    
def roc_curve_plot(y_test,pred_proba):
    fprs, tprs, thresholds = roc_curve(y_test,pred_proba) ## 입력시 1레이블 컬럼만 추출
    
    # Roc curve를 plot 곡선으로 기름
    plt.plot(fprs,tprs,label='ROC')
    ## 가운데 대각선 직선을 그림
    plt.plot([0,1],[0,1],"k--",label="ramdom")
    
    ## fpr x축을 scale을 0.1단위로 변경 x,y축 명 설정
    start,end = plt.xlim()
    plt.xticks(np.round(np.arange(start,end,0.1),2))
    plt.xlim(0,1)
    plt.ylim(0,1)
    plt.xlabel('FPR(1-sensitivity)')
    plt.ylabel('TPR(recall)')
    plt.legend()
    plt.show()

# %%
## 불균형 처리 안한 데이터 
train = pd.read_csv("./datasets/통계검증완료/코스닥_standard_train.csv",index_col=0)
test =  pd.read_csv("./datasets/통계검증완료/코스닥_standard_test.csv",index_col=0)

id_col = ['회사명', '거래소코드', '회계년도', '산업군','target_3']


최종_col_3 = ['abs(영업현금흐름-당기순이익)/매출액', '누적수익성비율', 'WW지수','금융비용부담률', 'TMD', '순운전자본비율']

X_train = train[최종_col_3]
y_train = train["target_3"]

X_test = test[최종_col_3]
y_test = test["target_3"]

# %% [markdown]
# # LSTM model

# %%
# LSTM 모델 정의
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1, activation='sigmoid'))


# 모델 컴파일
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# 모델 학습
model.fit(X_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 141/141 [==============================] - 10s 12ms/step - loss: 0.1840 - accuracy: 0.9676
# Epoch 2/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0949 - accuracy: 0.9721
# Epoch 3/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0851 - accuracy: 0.9758
# Epoch 4/100
# 141/141 [==============================] - 2s 11ms/step - loss: 0.0859 - accuracy: 0.9765
# Epoch 5/100
# 141/141 [==============================] - 2s 11ms/step - loss: 0.0849 - accuracy: 0.9756
# Epoch 6/100
# 141/141 [==============================] - 2s 11ms/step - loss: 0.0864 - accuracy: 0.9752
# Epoch 7/100
# 141/141 [==============================] - 2s 13ms/step - loss: 0.0845 - accuracy: 0.9767
# Epoch 8/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0846 - accuracy: 0.9776
# Epoch 9/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0837 - accuracy: 0.9772
# Epoch 10/100
# 141/141 [==============================] - 2s 14ms/step - loss: 0.0829 - accuracy: 0.9769
# Epoch 11/100
# 141/141 [==============================] - 2s 15ms/step - loss: 0.0846 - accuracy: 0.9767
# Epoch 12/100
# 141/141 [==============================] - 2s 13ms/step - loss: 0.0814 - accuracy: 0.9774
# Epoch 13/100
# 141/141 [==============================] - 2s 14ms/step - loss: 0.0830 - accuracy: 0.9769
# Epoch 14/100
# 141/141 [==============================] - 2s 15ms/step - loss: 0.0829 - accuracy: 0.9763
# Epoch 15/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0830 - accuracy: 0.9778
# Epoch 16/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0821 - accuracy: 0.9780
# Epoch 17/100
# 141/141 [==============================] - 2s 13ms/step - loss: 0.0811 - accuracy: 0.9774
# Epoch 18/100
# 141/141 [==============================] - 2s 13ms/step - loss: 0.0800 - accuracy: 0.9772
# Epoch 19/100
# 141/141 [==============================] - 2s 13ms/step - loss: 0.0811 - accuracy: 0.9769
# Epoch 20/100
# 141/141 [==============================] - 2s 15ms/step - loss: 0.0795 - accuracy: 0.9783
# Epoch 21/100
# 141/141 [==============================] - 2s 14ms/step - loss: 0.0794 - accuracy: 0.9785
# Epoch 22/100
# 141/141 [==============================] - 2s 15ms/step - loss: 0.0795 - accuracy: 0.9776
# Epoch 23/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0776 - accuracy: 0.9778
# Epoch 24/100
# 141/141 [==============================] - 2s 13ms/step - loss: 0.0784 - accuracy: 0.9778
# Epoch 25/100
# 141/141 [==============================] - 2s 16ms/step - loss: 0.0781 - accuracy: 0.9785
# Epoch 26/100
# 141/141 [==============================] - 2s 14ms/step - loss: 0.0783 - accuracy: 0.9763
# Epoch 27/100
# 141/141 [==============================] - 2s 13ms/step - loss: 0.0770 - accuracy: 0.9785
# Epoch 28/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0793 - accuracy: 0.9772
# Epoch 29/100
# 141/141 [==============================] - 2s 13ms/step - loss: 0.0755 - accuracy: 0.9789
# Epoch 30/100
# 141/141 [==============================] - 2s 13ms/step - loss: 0.0753 - accuracy: 0.9783
# Epoch 31/100
# 141/141 [==============================] - 2s 13ms/step - loss: 0.0766 - accuracy: 0.9778
# Epoch 32/100
# 141/141 [==============================] - 2s 14ms/step - loss: 0.0743 - accuracy: 0.9785
# Epoch 33/100
# 141/141 [==============================] - 2s 13ms/step - loss: 0.0746 - accuracy: 0.9776
# Epoch 34/100
# 141/141 [==============================] - 2s 14ms/step - loss: 0.0727 - accuracy: 0.9785
# Epoch 35/100
# 141/141 [==============================] - 2s 14ms/step - loss: 0.0720 - accuracy: 0.9785
# Epoch 36/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0724 - accuracy: 0.9807
# Epoch 37/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0727 - accuracy: 0.9785
# Epoch 38/100
# 141/141 [==============================] - 2s 14ms/step - loss: 0.0709 - accuracy: 0.9792
# Epoch 39/100
# 141/141 [==============================] - 2s 13ms/step - loss: 0.0715 - accuracy: 0.9796
# Epoch 40/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0684 - accuracy: 0.9805
# Epoch 41/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0706 - accuracy: 0.9798
# Epoch 42/100
# 141/141 [==============================] - 2s 14ms/step - loss: 0.0686 - accuracy: 0.9803
# Epoch 43/100
# 141/141 [==============================] - 2s 13ms/step - loss: 0.0689 - accuracy: 0.9789
# Epoch 44/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0688 - accuracy: 0.9796
# Epoch 45/100
# 141/141 [==============================] - 2s 13ms/step - loss: 0.0670 - accuracy: 0.9805
# Epoch 46/100
# 141/141 [==============================] - 2s 15ms/step - loss: 0.0679 - accuracy: 0.9798
# Epoch 47/100
# 141/141 [==============================] - 2s 16ms/step - loss: 0.0685 - accuracy: 0.9803
# Epoch 48/100
# 141/141 [==============================] - 2s 13ms/step - loss: 0.0665 - accuracy: 0.9800
# Epoch 49/100
# 141/141 [==============================] - 2s 13ms/step - loss: 0.0650 - accuracy: 0.9814
# Epoch 50/100
# 141/141 [==============================] - 2s 11ms/step - loss: 0.0641 - accuracy: 0.9803
# Epoch 51/100
# 141/141 [==============================] - 2s 14ms/step - loss: 0.0639 - accuracy: 0.9825
# Epoch 52/100
# 141/141 [==============================] - 2s 14ms/step - loss: 0.0652 - accuracy: 0.9805
# Epoch 53/100
# 141/141 [==============================] - 2s 13ms/step - loss: 0.0652 - accuracy: 0.9807
# Epoch 54/100
# 141/141 [==============================] - 2s 13ms/step - loss: 0.0615 - accuracy: 0.9823
# Epoch 55/100
# 141/141 [==============================] - 2s 13ms/step - loss: 0.0653 - accuracy: 0.9814
# Epoch 56/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0648 - accuracy: 0.9809
# Epoch 57/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0616 - accuracy: 0.9820
# Epoch 58/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0638 - accuracy: 0.9800
# Epoch 59/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0624 - accuracy: 0.9827
# Epoch 60/100
# 141/141 [==============================] - 2s 14ms/step - loss: 0.0641 - accuracy: 0.9818
# Epoch 61/100
# 141/141 [==============================] - 2s 13ms/step - loss: 0.0611 - accuracy: 0.9827
# Epoch 62/100
# 141/141 [==============================] - 2s 13ms/step - loss: 0.0608 - accuracy: 0.9823
# Epoch 63/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0623 - accuracy: 0.9827
# Epoch 64/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0609 - accuracy: 0.9825
# Epoch 65/100
# 141/141 [==============================] - 2s 11ms/step - loss: 0.0613 - accuracy: 0.9809
# Epoch 66/100
# 141/141 [==============================] - 2s 11ms/step - loss: 0.0589 - accuracy: 0.9831
# Epoch 67/100
# 141/141 [==============================] - 2s 11ms/step - loss: 0.0612 - accuracy: 0.9827
# Epoch 68/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0585 - accuracy: 0.9827
# Epoch 69/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0574 - accuracy: 0.9834
# Epoch 70/100
# 141/141 [==============================] - 2s 11ms/step - loss: 0.0568 - accuracy: 0.9838
# Epoch 71/100
# 141/141 [==============================] - 2s 11ms/step - loss: 0.0584 - accuracy: 0.9823
# Epoch 72/100
# 141/141 [==============================] - 2s 11ms/step - loss: 0.0568 - accuracy: 0.9823
# Epoch 73/100
# 141/141 [==============================] - 2s 11ms/step - loss: 0.0562 - accuracy: 0.9829
# Epoch 74/100
# 141/141 [==============================] - 2s 11ms/step - loss: 0.0582 - accuracy: 0.9825
# Epoch 75/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0568 - accuracy: 0.9825
# Epoch 76/100
# 141/141 [==============================] - 2s 11ms/step - loss: 0.0551 - accuracy: 0.9847
# Epoch 77/100
# 141/141 [==============================] - 2s 11ms/step - loss: 0.0547 - accuracy: 0.9827
# Epoch 78/100
# 141/141 [==============================] - 2s 11ms/step - loss: 0.0537 - accuracy: 0.9827
# Epoch 79/100
# 141/141 [==============================] - 2s 11ms/step - loss: 0.0542 - accuracy: 0.9838
# Epoch 80/100
# 141/141 [==============================] - 2s 11ms/step - loss: 0.0523 - accuracy: 0.9847
# Epoch 81/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0558 - accuracy: 0.9840
# Epoch 82/100
# 141/141 [==============================] - 2s 11ms/step - loss: 0.0539 - accuracy: 0.9831
# Epoch 83/100
# 141/141 [==============================] - 2s 11ms/step - loss: 0.0534 - accuracy: 0.9838
# Epoch 84/100
# 141/141 [==============================] - 2s 11ms/step - loss: 0.0529 - accuracy: 0.9836
# Epoch 85/100
# 141/141 [==============================] - 2s 11ms/step - loss: 0.0516 - accuracy: 0.9827
# Epoch 86/100
# 141/141 [==============================] - 2s 11ms/step - loss: 0.0512 - accuracy: 0.9838
# Epoch 87/100
# 141/141 [==============================] - 2s 11ms/step - loss: 0.0546 - accuracy: 0.9829
# Epoch 88/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0485 - accuracy: 0.9856
# Epoch 89/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0498 - accuracy: 0.9845
# Epoch 90/100
# 141/141 [==============================] - 2s 11ms/step - loss: 0.0478 - accuracy: 0.9845
# Epoch 91/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0474 - accuracy: 0.9847
# Epoch 92/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0483 - accuracy: 0.9845
# Epoch 93/100
# 141/141 [==============================] - 2s 14ms/step - loss: 0.0470 - accuracy: 0.9863
# Epoch 94/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0480 - accuracy: 0.9836
# Epoch 95/100
# 141/141 [==============================] - 2s 14ms/step - loss: 0.0474 - accuracy: 0.9854
# Epoch 96/100
# 141/141 [==============================] - 2s 15ms/step - loss: 0.0481 - accuracy: 0.9845
# Epoch 97/100
# 141/141 [==============================] - 2s 12ms/step - loss: 0.0486 - accuracy: 0.9845
# Epoch 98/100
# 141/141 [==============================] - 2s 13ms/step - loss: 0.0461 - accuracy: 0.9843
# Epoch 99/100
# 141/141 [==============================] - 2s 11ms/step - loss: 0.0461 - accuracy: 0.9856
# Epoch 100/100
# 141/141 [==============================] - 2s 13ms/step - loss: 0.0420 - accuracy: 0.9854

# %%
pred_proba = model.predict(X_test)
binarizer = Binarizer(threshold=0.25).fit(pred_proba) 
pred = binarizer.transform(pred_proba)
eval(pred=pred,test=y_test)
# Out:
# 80/80 [==============================] - 2s 4ms/step
# ##############
#  [[2457   20]
#  [  23   49]] ############
#  acc_score: 0.9831306394664574
#  f1_score: 0.6950354609929078
#  precision: 0.7101449275362319
#  recall: 0.6805555555555556

# %%
precision_recall_curve_plot(y_test,pred_proba)

# %%
roc_auc_score(y_test,pred_proba)
# Out:
# 0.9527037635132104

# %%
plot_pr_auc_curve(y_test,pred_proba)
get_pr_auc_score(y_test,pred_proba)
# Out:
# 0.7501091796882444

# %% [markdown]
# ## 다층 퍼셉트론

# %%
# MLP 모델 생성

model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(6,)))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer=Adam(lr=0.001), metrics=['accuracy'])


# 모델 컴파일
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# 모델 학습
model.fit(X_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# c:\Users\msi\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 141/141 [==============================] - 1s 2ms/step - loss: 0.3716 - accuracy: 0.9102
# Epoch 2/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.1585 - accuracy: 0.9654
# Epoch 3/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.1151 - accuracy: 0.9707
# Epoch 4/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.1007 - accuracy: 0.9701
# Epoch 5/100
# 141/141 [==============================] - 0s 3ms/step - loss: 0.0971 - accuracy: 0.9687
# Epoch 6/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0999 - accuracy: 0.9738
# Epoch 7/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0869 - accuracy: 0.9729
# Epoch 8/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0905 - accuracy: 0.9756
# Epoch 9/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0874 - accuracy: 0.9729
# Epoch 10/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0844 - accuracy: 0.9743
# Epoch 11/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0826 - accuracy: 0.9774
# Epoch 12/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0803 - accuracy: 0.9783
# Epoch 13/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0805 - accuracy: 0.9787
# Epoch 14/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0880 - accuracy: 0.9769
# Epoch 15/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0825 - accuracy: 0.9758
# Epoch 16/100
# 141/141 [==============================] - 0s 3ms/step - loss: 0.0814 - accuracy: 0.9763
# Epoch 17/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0767 - accuracy: 0.9780
# Epoch 18/100
# 141/141 [==============================] - 0s 3ms/step - loss: 0.0817 - accuracy: 0.9767
# Epoch 19/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0794 - accuracy: 0.9785
# Epoch 20/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0804 - accuracy: 0.9785
# Epoch 21/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0772 - accuracy: 0.9792
# Epoch 22/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0768 - accuracy: 0.9780
# Epoch 23/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0811 - accuracy: 0.9765
# Epoch 24/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0754 - accuracy: 0.9789
# Epoch 25/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0780 - accuracy: 0.9796
# Epoch 26/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0772 - accuracy: 0.9798
# Epoch 27/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0746 - accuracy: 0.9776
# Epoch 28/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0735 - accuracy: 0.9803
# Epoch 29/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0755 - accuracy: 0.9783
# Epoch 30/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0780 - accuracy: 0.9776
# Epoch 31/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0750 - accuracy: 0.9789
# Epoch 32/100
# 141/141 [==============================] - 0s 3ms/step - loss: 0.0730 - accuracy: 0.9789
# Epoch 33/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0808 - accuracy: 0.9792
# Epoch 34/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0700 - accuracy: 0.9794
# Epoch 35/100
# 141/141 [==============================] - 0s 3ms/step - loss: 0.0713 - accuracy: 0.9805
# Epoch 36/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0732 - accuracy: 0.9794
# Epoch 37/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0721 - accuracy: 0.9794
# Epoch 38/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0683 - accuracy: 0.9800
# Epoch 39/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0716 - accuracy: 0.9796
# Epoch 40/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0724 - accuracy: 0.9798
# Epoch 41/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0706 - accuracy: 0.9794
# Epoch 42/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0682 - accuracy: 0.9803
# Epoch 43/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0732 - accuracy: 0.9796
# Epoch 44/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0722 - accuracy: 0.9803
# Epoch 45/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0720 - accuracy: 0.9809
# Epoch 46/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0701 - accuracy: 0.9809
# Epoch 47/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0713 - accuracy: 0.9818
# Epoch 48/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0694 - accuracy: 0.9807
# Epoch 49/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0709 - accuracy: 0.9814
# Epoch 50/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0745 - accuracy: 0.9789
# Epoch 51/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0732 - accuracy: 0.9787
# Epoch 52/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0724 - accuracy: 0.9807
# Epoch 53/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0675 - accuracy: 0.9809
# Epoch 54/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0706 - accuracy: 0.9807
# Epoch 55/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0663 - accuracy: 0.9814
# Epoch 56/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0708 - accuracy: 0.9787
# Epoch 57/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0689 - accuracy: 0.9803
# Epoch 58/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0682 - accuracy: 0.9800
# Epoch 59/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0696 - accuracy: 0.9816
# Epoch 60/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0724 - accuracy: 0.9803
# Epoch 61/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0671 - accuracy: 0.9800
# Epoch 62/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0669 - accuracy: 0.9803
# Epoch 63/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0676 - accuracy: 0.9800
# Epoch 64/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0707 - accuracy: 0.9805
# Epoch 65/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0665 - accuracy: 0.9809
# Epoch 66/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0695 - accuracy: 0.9809
# Epoch 67/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0693 - accuracy: 0.9816
# Epoch 68/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0710 - accuracy: 0.9814
# Epoch 69/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0680 - accuracy: 0.9807
# Epoch 70/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0640 - accuracy: 0.9807
# Epoch 71/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0652 - accuracy: 0.9814
# Epoch 72/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0675 - accuracy: 0.9803
# Epoch 73/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0676 - accuracy: 0.9794
# Epoch 74/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0642 - accuracy: 0.9816
# Epoch 75/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0669 - accuracy: 0.9816
# Epoch 76/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0671 - accuracy: 0.9823
# Epoch 77/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0632 - accuracy: 0.9809
# Epoch 78/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0656 - accuracy: 0.9816
# Epoch 79/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0646 - accuracy: 0.9823
# Epoch 80/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0686 - accuracy: 0.9800
# Epoch 81/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0685 - accuracy: 0.9812
# Epoch 82/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0688 - accuracy: 0.9792
# Epoch 83/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0665 - accuracy: 0.9800
# Epoch 84/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0691 - accuracy: 0.9818
# Epoch 85/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0658 - accuracy: 0.9812
# Epoch 86/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0658 - accuracy: 0.9800
# Epoch 87/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0662 - accuracy: 0.9805
# Epoch 88/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0667 - accuracy: 0.9816
# Epoch 89/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0646 - accuracy: 0.9823
# Epoch 90/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0672 - accuracy: 0.9812
# Epoch 91/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0641 - accuracy: 0.9827
# Epoch 92/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0669 - accuracy: 0.9812
# Epoch 93/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0647 - accuracy: 0.9818
# Epoch 94/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0681 - accuracy: 0.9814
# Epoch 95/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0655 - accuracy: 0.9814
# Epoch 96/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0617 - accuracy: 0.9818
# Epoch 97/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0656 - accuracy: 0.9823
# Epoch 98/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0673 - accuracy: 0.9807
# Epoch 99/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0666 - accuracy: 0.9809
# Epoch 100/100
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0663 - accuracy: 0.9805

# %%
pred_proba = model.predict(X_test)
binarizer = Binarizer(threshold=0.25).fit(pred_proba) 
pred = binarizer.transform(pred_proba)
eval(pred=pred,test=y_test)
# Out:
# 80/80 [==============================] - 0s 4ms/step
# ##############
#  [[2457   20]
#  [  23   49]] ############
#  acc_score: 0.9831306394664574
#  f1_score: 0.6950354609929078
#  precision: 0.7101449275362319
#  recall: 0.6805555555555556

# %%
precision_recall_curve_plot(y_test,pred_proba)

# %%
roc_curve_plot(y_test,pred_proba)
roc_auc_score(y_test,pred_proba)
# Out:
# 0.9527037635132104

# %%
plot_pr_auc_curve(y_test,pred_proba)
get_pr_auc_score(y_test,pred_proba)
